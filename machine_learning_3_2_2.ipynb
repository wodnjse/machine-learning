# %% [markdown]
# <a href="https://colab.research.google.com/github/wodnjse/machine-learning/blob/main/machine_learning_3_2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 분류 문제
# - 분류문제: *데이터와 레이블(정답)으로 학습*한 모델에 <br/>-> 새로운 데이터가 입력되면 *어떤 범주인지* 예상하는 것
#
# # 분류 모델
# - 고정된 레이블을 나누기 위한 분류선 학습 후<br/>-> *새로운 입력*이 들어오면 여러 *클래스 중 하나*로 선택
# - 최근접이웃법(k-NN), 서포트 벡터 머신(SVM), 랜섬 포레스트 등
# ![image.png](data:image/png;base64,...)
#
# # 이진 분류와 다중 분류
# - 클래스 수로 분류
# ![image.png](data:image/png;base64,...)
#
# - 직선/곡선으로 분류<br/>
#
# ![image.png](data:image/png;base64,...)
#
# # 분류 모델 구현
# - *이진 분류*는 클래스가 2개: *어떤 것이 확률이 높은지* 확인하는 모델 생성
# - *로지스틱 회귀 모델*이 대표적: 예상 결괏값의 범위가 0~1 사이
# - 실습: 수확한 포도송이가 *거봉인지 아닌지* 판단하는 이진 분류 모델 구현
#
# # 포도송이 거봉 판단 수집 데이터
# - 실습: 수확한 포도송이가 *거봉인지 아닌지 판단하는 이진 분류 모델 구현
# - 독립변수: 포도 한 알의 크기, 포도 한 송이의 무게
# - 종속변수: 거봉 여부
#
# |포도 한 알 크기(mm)|포도 한 송이 무게(g)|거봉 여부|
# |------|---|---|
# |19|300|X|
# |20|500|X|
# |18|400|X|
# |25|500|O|
# |27|700|O|
# |28|800|O|
#
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# 데이터 입력

# 포도 한 알의 크기와 포도 한 송이의 무게는 정수: 그대로 입력
# 거봉 여부는 문자: 거봉이면 1, 거봉이 아니면 0으로 변환하여 입력

grape = np.array([[19,300,0], [20, 500, 0], [25, 500, 1], [27, 700, 1], [28, 600, 1]])

# %%
X = grape[:, :2] # 전체 행 중 0-1열
